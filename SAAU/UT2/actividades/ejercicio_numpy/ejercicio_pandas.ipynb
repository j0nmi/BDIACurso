# %% [markdown]
# # Ejercicio Pandas - Spyridon Fakiolas
# Fecha de entrega: 27 oct, 20:00
#
# Use el dataset de Spotify-2023.csv y responde a las siguientes preguntas:
# * Cargar el conjunto de datos en un archivo Jupyter Notebook de manera local. La codificación del conjunto de datos es latin-1.
# * ¿Cuál es el formato de los datos?
# * ¿Cuál es la dimensión de los datos?
# * Muestra un subconjunto de datos, por ejemplo las 5 primeras filas.
# * Muestra los datos de una característica del conjunto de datos.
# * Muestra las estadísticas descriptivas del conjunto de datos.
# * Muestra todas las características del conjunto de datos.
# * Muestra todos los tipos de datos que contiene el conjunto de datos.
# * Convierte la característica streams en numérica.
# * Inspecciona si hay valores nulos.
# * Sustituir los valores nulos por el valor medio de esta característica.
#
# Subir el archivo jupyter con el siguiente formato Apellido1Nombre_EjercicioPandas.ipynb

# %%
# Importamos las librerias necesarias
import pandas as pd
import numpy as np

# %% [markdown]
# Cargar el conjunto de datos en un archivo Jupyter Notebook de manera local.

# %%
df=pd.read_csv("../../python/spotify-2023.csv", encoding="latin-1")
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %% [markdown]
# ¿Cuál es el formato de los datos?

# %%
print(df.dtypes)
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %% [markdown]
# ¿Cuál es el formato de los datos?

# %%
print(df.shape)

# El resultado da: (953, 24), es decir; 953 filas y 24 columnas.
# Out:
# (953, 24)

# %% [markdown]
# Muestra un subconjunto de datos, por ejemplo las 5 primeras filas.

# %%
# Muestra las 5 primeras filas
print(df.head(5))
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %% [markdown]
# Muestra los datos de una característica del conjunto de datos.

# %%
# Mostramos el nombre de la canción por ejemplo
print(df["track_name"])

# Mostramos el nombre de la canción y el cantante
print(df[["track_name", "artist(s)_name"]])
# Out:
# 0      Seven (feat. Latto) (Explicit Ver.)
# 1                                     LALA
# 2                                  vampire
# 3                             Cruel Summer
# 4                           WHERE SHE GOES
#                       ...
# 948                           My Mind & Me
# 949              Bigger Than The Whole Sky
# 950                   A Veces (feat. Feid)
# 951                          En La De Ella
# 952                                  Alone
# Name: track_name, Length: 953, dtype: object
#                               track_name      artist(s)_name
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook
# 1                                   LALA         Myke Towers
# 2                                vampire      Olivia Rodrigo
# 3                           Cruel Summer        Taylor Swift
# 4                         WHERE SHE GOES           Bad Bunny
# ..                                   ...                 ...
# ...

# %% [markdown]
# Muestra las estadísticas descriptivas del conjunto de datos.

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
# Muestra todas las características del conjunto de datos.

# %%
# Mostramos las características en formato lista
# Cambiamos el separador para msotrarlo "Bonito"
lista = df.columns.tolist()
print(*lista, sep='\n')
# Out:
# track_name
# artist(s)_name
# artist_count
# released_year
# released_month
# released_day
# in_spotify_playlists
# in_spotify_charts
# streams
# in_apple_playlists
# in_apple_charts
# in_deezer_playlists
# in_deezer_charts
# in_shazam_charts
# bpm
# key
# mode
# danceability_%
# valence_%
# energy_%
# acousticness_%
# instrumentalness_%
# liveness_%
# speechiness_%

# %% [markdown]
# Muestra todos los tipos de datos que contiene el conjunto de datos.

# %%
print(df.dtypes)
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %% [markdown]
# Convierte la característica streams en numérica.

# %%
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# %% [markdown]
# Inspecciona si hay valores nulos.

# %%
print("Recuento de valores nulos: ")
print(df.isnull().sum())
# Out:
# Recuento de valores nulos:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  1
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %% [markdown]
# Sustituir los valores nulos por el valor medio de esta característica.

# %%
df['streams'].fillna(df['streams'].mean(), inplace=True)

# Volvemos a ver para comprobar que haya funcionado
print("Recuento de valores nulos: ")
print(df.isnull().sum())
# Out:
# Recuento de valores nulos:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %% [markdown]
# Limpiamos los datos

# %%
# Verificación de datos nulos uno a uno (False si no es nulo y True si lo es)
print("Datos nulos en el DataFrame:")
print(df.isnull())
print("Para saber cuántos valores nulos tenemos por columnas:")
print(df.isnull().sum())

# Eliminar filas con valores nulos
print("Para eliminar las filas con valores nulos:")
print(df.dropna())
# Out:
# Datos nulos en el DataFrame:
#      track_name  artist(s)_name  artist_count  released_year  released_month  \
# 0         False           False         False          False           False
# 1         False           False         False          False           False
# 2         False           False         False          False           False
# 3         False           False         False          False           False
# 4         False           False         False          False           False
# ..          ...             ...           ...            ...             ...
# 948       False           False         False          False           False
# 949       False           False         False          False           False
# 950       False           False         False          False           False
# 951       False           False         False          False           False
# 952       False           False         False          False           False
#
# ...

# %% [markdown]
# Exportamos los datos procesados

# %%
df.to_csv("spotifyTerminado.csv")
